# %%
import pandas as pd
import numpy as np
import math
from datetime import datetime, timedelta
import warnings
warnings.filterwarnings('ignore')

# %%
pd.set_option('display.float_format', lambda x: '%.02f' % x)

# %%
def category_fill(df,cat_column_name,category_list,categories_prob_list):
    df[cat_column_name] = np.random.choice(category_list,df.shape[0],p=categories_prob_list) 
    return df


def sub_category_fill(df,cat_column_name,sub_cat_column_name,sub_categories_prob_dict): 
    df_new = pd.DataFrame()
    for key,value in sub_categories_prob_dict.items():
        df1 = df[df[cat_column_name]==key]
        df1= category_fill(df1,sub_cat_column_name,value[0],value[1])
        df_new = pd.concat([df_new,df1],axis=0)  
    return df_new

# %% [markdown]
# # PIL_Vintage

# %%
df_vintage =pd.DataFrame(columns=['open_mon','mob','final_acq_channel','final_campaign_id','ita_t_c_flag','term_band',
                                  'resp_channel','package','fico_band','STATUS_CD','acct_count',
                                  'auto_deduct','citi_auto_deduct','opening_balance','balance','interest','payment',
                                  'tot_fees','gcl','recoveries','NCL','cof','book_amt','apr_wtd_line','apr_wtd_bal',
                                  'portf_fico','app_fico','durtn'                            
                                     ])
df_vintage
# Out:
# Empty DataFrame
# Columns: [open_mon, mob, final_acq_channel, final_campaign_id, ita_t_c_flag, term_band, resp_channel, package, fico_band, STATUS_CD, acct_count, auto_deduct, citi_auto_deduct, opening_balance, balance, interest, payment, tot_fees, gcl, recoveries, NCL, cof, book_amt, apr_wtd_line, apr_wtd_bal, portf_fico, app_fico, durtn]
# Index: []
#
# [0 rows x 28 columns]

# %%
# idx = pd.date_range(start='2018-01-31', end='2023-08-31', freq='M')
# df_fee_curve['RECV_YYMM']=idx
# df_fee_curve['RECV_YYMM']=df_fee_curve['RECV_YYMM'].apply(lambda x: datetime.strptime(str(x)[:-9],'%Y-%m-%d').strftime('%Y%m'))

df_vintage['open_mon'] =['201901']*1000


df_vintage = category_fill(df_vintage,'mob',['0','1','2'],[0.4,0.4,0.2])
df_vintage = category_fill(df_vintage,'final_acq_channel',['No Reln BAU','P2C 1.0','P2D ITA 2018_2020','P2D ITA/Organic'],[0.085,0.009,0.585,0.321])

df_vintage = category_fill(df_vintage,'final_campaign_id',['?','ITA1810','ITA1812'],[0.4,0.06,0.54])


df_vintage = category_fill(df_vintage,'ita_t_c_flag',['?','C','T'],[0.4,0.2,0.4])

df_vintage = category_fill(df_vintage,'term_band',['a. Term 1-12','b. Term 13-24','c. Tem 25-36','d. Term 37-48','e. Term 49-60'],
                           [0.15,0.15,0.25,0.15,0.3])


df_vintage = category_fill(df_vintage,'resp_channel',['BRANCH','ONLINE','TELE-SALE'],[0.4,0.3,0.3])

df_vintage = category_fill(df_vintage,'package',['?','Cards','CitiBlue','CitiGold','CitiPriority','Employee'],
                           [0.1,0.05,0.65,0.05,0.1,0.05])

df_vintage = category_fill(df_vintage,'package',['?','Cards','CitiBlue','CitiGold','CitiPriority','Employee'],
                           [0.1,0.05,0.65,0.05,0.1,0.05])

fico_list= ['<710','710-740','740-780','780+']
df_vintage['fico_band'] = np.random.choice(fico_list,df_vintage.shape[0],p=[0.26,0.26,0.22,0.26])

df_vintage['STATUS_CD'] = 'ACT'

df_vintage['acct_count']= np.random.randint(0,368,df_vintage.shape[0])
df_vintage['auto_deduct']= np.random.randint(0,354,df_vintage.shape[0])
df_vintage['citi_auto_deduct']= np.random.randint(0,354,df_vintage.shape[0])

df_vintage['opening_balance']= np.random.uniform(611,5899447,df_vintage.shape[0])

df_vintage['interest']= np.random.uniform(-8.21,52525,df_vintage.shape[0])

df_vintage['payment']= np.random.uniform(0,196866,df_vintage.shape[0])

df_vintage['tot_fees']= np.random.randint(0,25,df_vintage.shape[0])

df_vintage['gcl']= 0

df_vintage['recoveries']= 0

df_vintage['NCL']= 0

df_vintage['cof']= np.random.uniform(-12531,-1.53,df_vintage.shape[0])

df_vintage['book_amt']= np.random.uniform(2000,5956335,df_vintage.shape[0])

df_vintage['apr_wtd_line']= np.random.uniform(27480,65442758,df_vintage.shape[0])

df_vintage['apr_wtd_bal']= np.random.uniform(4732,65139904,df_vintage.shape[0])

df_vintage['portf_fico']= np.random.uniform(0,255948,df_vintage.shape[0])

df_vintage['app_fico']= np.where(df_vintage['fico_band']=='<710', 696,
                                     np.where(df_vintage['fico_band']=='710-740',720,
                                             np.where(df_vintage['fico_band']=='740-780',755,790)))


duration = list(range(12,22080,12))
df_vintage['durtn']= np.random.choice(duration,df_vintage.shape[0])

df_vintage

table_name= 'vintage_summary_'
df_vintage.columns = [table_name+i for i in df_vintage.columns]

df_info = pd.DataFrame(columns=['column_name','Data_type'])
df_info['column_name'] = df_vintage.columns.tolist()
for i in range(df_info.shape[0]):
    df_info['Data_type'][i] = df_vintage[df_info['column_name'][i]].dtype
    
df_revenue.to_csv('PIL_vintage_summary.csv', index=False)
df_info.to_csv( 'PIL_vintage_summary_data_types.csv',index=False)
# Out:
#     open_mon mob  final_acq_channel final_campaign_id ita_t_c_flag  \
# 0     201901   0    P2D ITA/Organic           ITA1812            ?
# 1     201901   1  P2D ITA 2018_2020           ITA1812            ?
# 2     201901   2  P2D ITA 2018_2020           ITA1812            ?
# 3     201901   0  P2D ITA 2018_2020           ITA1812            T
# 4     201901   1  P2D ITA 2018_2020           ITA1812            C
# ..       ...  ..                ...               ...          ...
# 995   201901   1  P2D ITA 2018_2020           ITA1812            T
# 996   201901   1  P2D ITA 2018_2020                 ?            T
# 997   201901   0    P2D ITA/Organic           ITA1812            T
# 998   201901   1  P2D ITA 2018_2020                 ?            T
# 999   201901   1  P2D ITA 2018_2020                 ?            T
#
#          term_band resp_channel       package fico_band STATUS_CD  ...  \
# 0     c. Tem 25-36       ONLINE      CitiBlue   740-780       ACT  ...
# ...

# %%
duration = list(range(12,22080,12))
np.random.choice(duration,5)

# %% [markdown]
# # PIL_portfolio

# %%
df_portfolio =pd.DataFrame(columns=['mon','final_acq_channel','final_campaign_id','ita_t_c_flag','term_band',
                                  'resp_channel','package','fico_band','STATUS_CD','acct_count',
                                    'new_loans','new_loan_amt',
                                  'auto_deduct','citi_auto_deduct','opening_balance','balance','interest','payment',
                                  'tot_fees','gcl','recoveries','NCL','cof','book_amt','apr_wtd_line','apr_wtd_bal',
                                  'portf_fico','app_fico','durtn'                            
                                     ])
df_portfolio
# Out:
# Empty DataFrame
# Columns: [mon, final_acq_channel, final_campaign_id, ita_t_c_flag, term_band, resp_channel, package, fico_band, STATUS_CD, acct_count, new_loans, new_loan_amt, auto_deduct, citi_auto_deduct, opening_balance, balance, interest, payment, tot_fees, gcl, recoveries, NCL, cof, book_amt, apr_wtd_line, apr_wtd_bal, portf_fico, app_fico, durtn]
# Index: []
#
# [0 rows x 29 columns]

# %%
df_portfolio['mon'] =['201901']*1000


# df_portfolio = category_fill(df_portfolio,'mob',['0','1','2'],[0.4,0.4,0.2])
df_portfolio = category_fill(df_portfolio,'final_acq_channel',['No Reln BAU','P2C 1.0','P2D ITA 2018_2020','P2D ITA/Organic'],[0.085,0.009,0.585,0.321])

df_portfolio = category_fill(df_portfolio,'final_campaign_id',['?','ITA1810','ITA1812'],[0.4,0.06,0.54])


df_portfolio = category_fill(df_portfolio,'ita_t_c_flag',['?','C','T'],[0.4,0.2,0.4])

df_portfolio = category_fill(df_portfolio,'term_band',['a. Term 1-12','b. Term 13-24','c. Tem 25-36','d. Term 37-48','e. Term 49-60'],
                           [0.15,0.15,0.25,0.15,0.3])


df_portfolio = category_fill(df_portfolio,'resp_channel',['BRANCH','ONLINE','TELE-SALE'],[0.4,0.3,0.3])

df_portfolio = category_fill(df_portfolio,'package',['?','Cards','CitiBlue','CitiGold','CitiPriority','Employee'],
                           [0.1,0.05,0.65,0.05,0.1,0.05])

df_portfolio = category_fill(df_portfolio,'package',['?','Cards','CitiBlue','CitiGold','CitiPriority','Employee'],
                           [0.1,0.05,0.65,0.05,0.1,0.05])

fico_list= ['<710','710-740','740-780','780+']
df_portfolio['fico_band'] = np.random.choice(fico_list,df_portfolio.shape[0],p=[0.26,0.26,0.22,0.26])

df_portfolio['STATUS_CD'] = 'ACT'

df_portfolio['acct_count']= [int(i) for i in np.random.randint(0,368,df_portfolio.shape[0])]

df_portfolio['new_loans']= [int(i) for i in np.random.uniform(0,26,df_portfolio.shape[0])]

df_portfolio['new_loan_amt']= np.random.uniform(0,154000,df_portfolio.shape[0])

df_portfolio['auto_deduct']= np.random.randint(0,354,df_portfolio.shape[0])

df_portfolio['citi_auto_deduct']= np.random.randint(0,354,df_portfolio.shape[0])

df_portfolio['opening_balance']= np.random.uniform(611,5899447,df_portfolio.shape[0])

df_portfolio['interest']= np.random.uniform(-8.21,52525,df_portfolio.shape[0])

df_portfolio['payment']= np.random.uniform(0,196866,df_portfolio.shape[0])

df_portfolio['tot_fees']= np.random.randint(0,25,df_portfolio.shape[0])

df_portfolio['gcl']= 0

df_portfolio['recoveries']= 0

df_portfolio['NCL']= 0

df_portfolio['cof']= np.random.uniform(-12531,-1.53,df_portfolio.shape[0])

df_portfolio['book_amt']= np.random.uniform(2000,5956335,df_portfolio.shape[0])

df_portfolio['apr_wtd_line']= np.random.uniform(27480,65442758,df_portfolio.shape[0])

df_portfolio['apr_wtd_bal']= np.random.uniform(4732,65139904,df_portfolio.shape[0])

df_portfolio['portf_fico']= np.random.uniform(0,255948,df_portfolio.shape[0])

df_portfolio['app_fico']= np.where(df_portfolio['fico_band']=='<710', 696,
                                     np.where(df_portfolio['fico_band']=='710-740',720,
                                             np.where(df_portfolio['fico_band']=='740-780',755,790)))


duration = list(range(12,22080,12))
df_portfolio['durtn']= np.random.choice(duration,df_portfolio.shape[0])

df_portfolio

table_name= 'portfolio_summary_'
df_portfolio.columns = [table_name+i for i in df_portfolio.columns]

df_info = pd.DataFrame(columns=['column_name','Data_type'])
df_info['column_name'] = df_portfolio.columns.tolist()
for i in range(df_info.shape[0]):
    df_info['Data_type'][i] = df_portfolio[df_info['column_name'][i]].dtype
    
df_revenue.to_csv('PIL_portfolio_summary.csv', index=False)
df_info.to_csv( 'PIL_portfolio_summary_data_types.csv',index=False)

# %% [markdown]
# # Balcon Tracking

# %%
# Balcon Tracking

df_bal_tracking =pd.DataFrame(columns=['product','channel','acq_date','MOB','acq_month','subchannel_source',
                                      'fico_bkt','balcon_ind','balcon_transfer_monthly','accts','avg_FICO','avg_credit_lt'])


df_bal_tracking
# Out:
# Empty DataFrame
# Columns: [product, channel, acq_date, MOB, acq_month, subchannel_source, fico_bkt, balcon_ind, balcon_transfer_monthly, accts, avg_FICO, avg_credit_lt]
# Index: []

# %%
idx = pd.date_range(start='2018-01-31', end='2023-08-31', freq='D')
df_bal_tracking['acq_date']=idx
df_bal_tracking['acq_month']=df_bal_tracking['acq_date'].apply(lambda x: datetime.strptime(str(x)[:-9],'%Y-%m-%d').strftime('%y-%b'))


fico_list= ['<710','710-740','740-780','780+']
df_bal_tracking['fico_bkt'] = np.random.choice(fico_list,df_bal_tracking.shape[0],p=[0.26,0.26,0.22,0.26])


df_bal_tracking = category_fill(df_bal_tracking,'subchannel_source',
                                ['App-By-Phone','Citi Affiliates','Citicards.com',
                                'External Affiliates','Paid Media','Paid Search','PS email'],
                                [0.012,0.052,0.324,0.293,0.025,0.192,0.102]).sort_values(by=['acq_date'])

df_bal_tracking['MOB']= np.random.randint(0,30,df_bal_tracking.shape[0])
df_bal_tracking['product'] ='Citi Rewards+'

df_bal_tracking['channel'] = 'Internet'

df_bal_tracking = category_fill(df_bal_tracking,'balcon_ind',
                                ['1','0'],[0.25,0.75]).sort_values(by=['acq_date'])

df_bal_tracking['balcon_transfer_monthly']= np.random.uniform(0,125833,df_bal_tracking.shape[0])
df_bal_tracking['accts']= [int(i) for i in np.random.uniform(0,92,df_bal_tracking.shape[0])]

df_bal_tracking['avg_credit_lt']= np.random.uniform(1000,16800,df_bal_tracking.shape[0])

df_bal_tracking['avg_FICO']= np.where(df_bal_tracking['fico_bkt']=='<710', 696,
                                     np.where(df_bal_tracking['fico_bkt']=='710-740',720,
                                             np.where(df_bal_tracking['fico_bkt']=='740-780',755,790)))


table_name= 'balcon_tracking_'
df_bal_tracking.columns = [table_name+i for i in df_bal_tracking.columns]

df_info = pd.DataFrame(columns=['column_name','Data_type'])
df_info['column_name'] = df_bal_tracking.columns.tolist()
for i in range(df_info.shape[0]):
    df_info['Data_type'][i] = df_bal_tracking[df_info['column_name'][i]].dtype
    

df_bal_tracking.sample(1000).to_csv('balcon_tracking.csv', index=False)
df_info.to_csv('balcon_tracking_data_types.csv', index=False)

# %% [markdown]
# # Balcon Fee Curve

# %%
df_fee_curve =pd.DataFrame(columns=['FICO','Balcon_type','RECV_YYMM', 'MOB','dur_resp','fee_charged','transfer_amt',
                                    'promo_bal','flip_amt','pay_amt','fee_amort','acct'
                                     ])
df_fee_curve
# Out:
# Empty DataFrame
# Columns: [FICO, Balcon_type, RECV_YYMM, MOB, dur_resp, fee_charged, transfer_amt, promo_bal, flip_amt, pay_amt, fee_amort, acct]
# Index: []

# %%
idx = pd.date_range(start='2018-01-31', end='2023-08-31', freq='D')
df_fee_curve['RECV_YYMM']=idx
df_fee_curve['RECV_YYMM']=df_fee_curve['RECV_YYMM'].apply(lambda x: datetime.strptime(str(x)[:-9],'%Y-%m-%d').strftime('%Y%m'))


fico_list= ['<710','710-740','740-780','780+']
df_fee_curve['FICO'] = np.random.choice(fico_list,df_fee_curve.shape[0],p=[0.26,0.26,0.22,0.26])

df_fee_curve = category_fill(df_fee_curve,'Balcon_type',['ACQ','ECM','RTN'],[0.28,0.6,0.12])

df_fee_curve['MOB']= np.random.randint(0,30,df_fee_curve.shape[0])
df_fee_curve['dur_resp']= np.random.randint(1,37,df_fee_curve.shape[0])

df_fee_curve['MOB']= np.random.randint(0,30,df_fee_curve.shape[0])

df_fee_curve['acct']= [int(i) for i in np.random.uniform(1,30763,df_fee_curve.shape[0])]
df_fee_curve['fee_charged']= np.random.uniform(0,1550029,df_fee_curve.shape[0])
df_fee_curve['transfer_amt']= np.random.uniform(0,41507374,df_fee_curve.shape[0])
df_fee_curve['promo_bal']= np.random.uniform(0,133621875,df_fee_curve.shape[0])
df_fee_curve['flip_amt']= np.random.uniform(0,4298670,df_fee_curve.shape[0])
df_fee_curve['pay_amt']= np.random.uniform(0,9252389,df_fee_curve.shape[0])
df_fee_curve['fee_amort']= np.random.uniform(0,457974,df_fee_curve.shape[0])

table_name= 'balcon_fee_curve_'
df_fee_curve.columns = [table_name+i for i in df_fee_curve.columns]

df_info = pd.DataFrame(columns=['column_name','Data_type'])
df_info['column_name'] = df_fee_curve.columns.tolist()
for i in range(df_info.shape[0]):
    df_info['Data_type'][i] = df_fee_curve[df_info['column_name'][i]].dtype
    

df_fee_curve.sample(1000).to_csv('df_fee_curve.csv', index=False)
df_info.to_csv('df_fee_curve_data_types.csv', index=False)
# Out:
#          FICO Balcon_type RECV_YYMM  MOB  dur_resp  fee_charged  transfer_amt  \
# 0     740-780         ECM    201801    1        31   1193766.14   16128997.42
# 1     740-780         ECM    201802    8        28   1300837.54   39542113.22
# 2        <710         ECM    201802    8        27   1327414.57    5018935.22
# 3     740-780         ECM    201802   28        18   1059260.72   39595301.29
# 4     710-740         ACQ    201802   29        24    573436.19   28580347.37
# ...       ...         ...       ...  ...       ...          ...           ...
# 2034  740-780         ECM    202308   22        29   1496235.61   38800145.60
# 2035     780+         ECM    202308   24        35    722049.83   14084053.89
# 2036     780+         ECM    202308    5        34    911464.86   32355292.75
# 2037     780+         ECM    202308   16         8   1054320.77   27574642.16
# 2038  710-740         ECM    202308   14        16    607374.41   14695707.84
#
# ...

# %% [markdown]
# # Rajat-attrition_rev_drivers_questions CSV

# %%
df_data = [[1, 'Direct',
        'How many accounts had any sales activity in July 2022.',
        'Revenue Drivers', 'DRIVERS_REV_CARDS'],
       [2, 'Deep-dive',
        'What percent of total sales is coming from digital transactions in the July 2022?',
        'Revenue Drivers', 'DRIVERS_REV_CARDS'],
       [3, 'Driver Based',
        'Give me the  net revenue for July 2022 portfoliowise.',
        'Revenue Drivers', 'DRIVERS_REV_CARDS'],
       [4, 'Direct',
        'Which card has the highest amount of net revenue for the July 2022?',
        'Revenue Drivers', 'DRIVERS_REV_CARDS'],
       [5, 'Direct',
        'Show me the net revenue spread grouped by fico values?',
        'Revenue Drivers', 'DRIVERS_REV_CARDS'],
       [6, 'Driver Based',
        'Which card has the highest percentage amount of collected interchange as a percent of net revenue in July 2022?',
        'Revenue Drivers', 'DRIVERS_REV_CARDS'],
       [7, 'Driver Based',
        'Which card has the highest revenue in terms of digital transactions?',
        'Revenue Drivers', 'DRIVERS_REV_CARDS'],
       [8, 'Deep-dive',
        'Show me the revenue per transaction across all cards.',
        'Revenue Drivers', 'DRIVERS_REV_CARDS'],
       [9, 'Direct',
        'How much the forex fee contributed to the net revenue in July 2022.',
        'Revenue Drivers', 'DRIVERS_REV_CARDS'],
       [10, 'Direct',
        'How much percentage of total fees is coming from balance consolidated fees?',
        'Revenue Drivers', 'DRIVERS_REV_CARDS'],
       [11, 'Direct',
        'What was the net amount collected as interchange July 2022?',
        'Revenue Drivers', 'DRIVERS_REV_CARDS'],
       [12, 'Deep-dive',
        'Which wallet segment is contributing to highest number of online transactions?',
        'Revenue Drivers', 'DRIVERS_REV_CARDS'],
       [13, 'Direct',
        'Give me the reason description because of which most customers attrited.',
        'Attrition', 'accdb.xlsx'],
       [14, 'Direct',
        'How many accounts were writed off in the current billing cycle.',
        'Attrition', 'accdb.xlsx'],
       [15, 'Direct',
        'Which card portfolio has the highest number of customers attrited in the current billing cycle.',
        'Attrition', 'accdb.xlsx'],
       [16, 'Deep-dive',
        'Show me the %age of voluntary closed accounts Portfoliowise.',
        'Attrition', 'accdb.xlsx'],
       [17, 'Deep-dive',
        'How many customer accounts were considered as gross credit loss accounts in the current billing cycle?',
        'Attrition', 'accdb.xlsx'],
       [18, 'Direct',
        'How many accounts were considered bankrupt for the current billing cycle?',
        'Attrition', 'accdb.xlsx'],
       [19, 'Direct',
        "Show me the number of customer's got attrited by vintage year groups.",
        'Attrition', 'accdb.xlsx'],
       [20, 'Deep-dive',
        'Which category of cards has the lowest number of attrited accounts for the current billing cycle?',
        'Attrition', 'accdb.xlsx'],
       [21, 'Direct',
        'Which card category has the highest amount of net interest in July 2022 ?',
        'Revenue Drivers', 'DRIVERS_REV_CARDS'],
       [22, 'Deep-dive',
        'Give me the net revenue distribution segmented by transactors and revolvers.',
        'Revenue Drivers', 'DRIVERS_REV_CARDS'],
       [23, 'Deep-dive',
        'Show me the net revenue spread grouped by wallet segments?',
        'Revenue Drivers', 'DRIVERS_REV_CARDS']]

cols= ['Sr. No.', 'Category', 'Questions', 'Pulse Dashboard', 'Dataset']
new_df = pd.DataFrame(df_data, columns=cols)

new_df.to_csv('rajat_questions.csv', index=False)

# %%
import pandas as pd
import numpy as np
import math
import random
from datetime import datetime

# %% [markdown]
# **COSTCO ACQUISITION DASHBOARD**

# %% [markdown]
# ****costco_acquisition_sm_table1 ****

# %%
import pandas as pd
import numpy as np
import random


df_costco_acquisition_sm_table1 = pd.DataFrame(columns=[
    'costco_acquisition_sm_table1_open_time',
    'costco_acquisition_sm_table1_sub_channel_info',
    'costco_acquisition_sm_table1_warehouse_region_cd',
    'costco_acquisition_sm_table1_portf_id',
    'costco_acquisition_sm_table1_membership_type',
    'costco_acquisition_sm_table1_membership_role',
    'costco_acquisition_sm_table1_fico_band',
    'costco_acquisition_sm_table1_tt_card',
    'costco_acquisition_sm_table1_p_m_1year', 
    'costco_acquisition_sm_table1_trip_dub',
    'costco_acquisition_sm_table1_credit_line_range',
    'costco_acquisition_sm_table1_approved_tag',
    'costco_acquisition_sm_table1_applications',
    'costco_acquisition_sm_table1_approved',
    'costco_acquisition_sm_table1_fico_sum',
    'costco_acquisition_sm_table1_fico_sum_appl',
    'costco_acquisition_sm_table1_credit_limit',
    'costco_acquisition_sm_table1_tt_card_num',
    'costco_acquisition_sm_table1_as_of_dt',
    'costco_acquisition_sm_table1_channel_detail',
    'costco_acquisition_sm_table1_pera_chnl' 
])

num_rows = 1000
all_yyyymm = [str(year) + str(month).zfill(2) for year in range(2016, 2024) for month in range(1, 13)]
all_yyyymm = [yyyymm for yyyymm in all_yyyymm if yyyymm <= '202309']
all_yyyymm = [yyyymm for yyyymm in all_yyyymm if yyyymm >= '201606']
ran_yyyymm = [random.choice(all_yyyymm) for _ in range(num_rows)]
df_costco_acquisition_sm_table1['costco_acquisition_sm_table1_open_time'] = ran_yyyymm

costco_acquisition_sm_table1_sub_channel_info = ['Citi Email','Citi Retail','Citi Sites','Costco Collateral','Costco Email',
                    'Costco Sites','External Sites','ITA','NULL','PA','Warehouse']
df_costco_acquisition_sm_table1['costco_acquisition_sm_table1_sub_channel_info'] = np.random.choice(costco_acquisition_sm_table1_sub_channel_info, df_costco_acquisition_sm_table1.shape[0],p=[0.00,0.02,0.12,0.06,0.01,0.13,0.08,0.01,0.00,0.01,0.56])

costco_acquisition_sm_table1_warehouse_region_cd = ['-','BA','BD','LA','MW',
                    'NE','NULL','NW','SD','SE','TE']
df_costco_acquisition_sm_table1['costco_acquisition_sm_table1_warehouse_region_cd'] = np.random.choice(costco_acquisition_sm_table1_warehouse_region_cd, df_costco_acquisition_sm_table1.shape[0],p=[0.43,0.07,0.03,0.07,0.07,0.06,0.03,0.07,0.07,0.06,0.04])

costco_acquisition_sm_table1_portf_id = ['520','521','522']
df_costco_acquisition_sm_table1['costco_acquisition_sm_table1_portf_id'] = np.random.choice(costco_acquisition_sm_table1_portf_id, df_costco_acquisition_sm_table1.shape[0],p=[0.65,0.13,0.22])

costco_acquisition_sm_table1_membership_type = ['B','E','G','o']
df_costco_acquisition_sm_table1['costco_acquisition_sm_table1_membership_type'] = np.random.choice(costco_acquisition_sm_table1_membership_type, df_costco_acquisition_sm_table1.shape[0],p=[0.35,0.07,0.56,0.02])

costco_acquisition_sm_table1_membership_role = ['0','1']
df_costco_acquisition_sm_table1['costco_acquisition_sm_table1_membership_role'] = np.random.choice(costco_acquisition_sm_table1_membership_role, df_costco_acquisition_sm_table1.shape[0],p=[0.35,0.65])

costco_acquisition_sm_table1_fico_band = ["<600", "600-629","630-659","660-699","700-749","750-799", "800-849","850","Invalid","Null"]
df_costco_acquisition_sm_table1['costco_acquisition_sm_table1_fico_band'] = np.random.choice(costco_acquisition_sm_table1_fico_band, df_costco_acquisition_sm_table1.shape[0],p=[0.05,0.07,0.10,0.12,0.15,0.18,0.17,0.10,0.03,0.03])


costco_acquisition_sm_table1_tt_card = ["SameDay","1_30Days","31_365days","365_PlusDays","X_INV"]
df_costco_acquisition_sm_table1['costco_acquisition_sm_table1_tt_card'] = np.random.choice(costco_acquisition_sm_table1_tt_card, df_costco_acquisition_sm_table1.shape[0],p=[0.19,0.12,0.20,0.47,0.02])


costco_acquisition_sm_table1_p_m_1year= [0,1,-2]
df_costco_acquisition_sm_table1['costco_acquisition_sm_table1_p_m_1year'] = np.random.choice(costco_acquisition_sm_table1_p_m_1year, df_costco_acquisition_sm_table1.shape[0],p=[0.47,0.51,0.02])


costco_acquisition_sm_table1_trip_dub= ["DoublePlay","Exec","Goldstar","NoMbrdate","TriplePlay"]
df_costco_acquisition_sm_table1['costco_acquisition_sm_table1_trip_dub'] = np.random.choice(costco_acquisition_sm_table1_trip_dub, df_costco_acquisition_sm_table1.shape[0],p=[0.06,0.50,0.31,0.00,0.13])


costco_acquisition_sm_table1_credit_line_range= ["-4","LT_2.9K","3K-3.9K","4K-9.9K","10K-11K","12K_PLus"]
df_costco_acquisition_sm_table1['costco_acquisition_sm_table1_credit_line_range'] = np.random.choice(costco_acquisition_sm_table1_credit_line_range, df_costco_acquisition_sm_table1.shape[0],p=[0.41,0.07,0.03,0.29,0.10,0.10])



random_values = np.random.normal(loc=17.7,scale=2, size=num_rows) 
random_values = np.clip(random_values,1, 1068)
df_costco_acquisition_sm_table1 ['costco_acquisition_sm_table1_applications'] = random_values.round().astype (int)

random_values = np.random.normal(loc=9.68,scale =1,size=num_rows) 
random_values = np.clip(random_values,1, 1040)
df_costco_acquisition_sm_table1 ['costco_acquisition_sm_table1_approved'] = random_values.round().astype (int)


df_costco_acquisition_sm_table1['costco_acquisition_sm_table1_approved_tag'] = df_costco_acquisition_sm_table1['costco_acquisition_sm_table1_approved'].map(lambda x: 1 if x != 0 else 0)

random_values = np.random.normal(loc=7348,scale =753.5,size=num_rows) 
random_values = np.clip(random_values,0, 754568)
df_costco_acquisition_sm_table1 ['costco_acquisition_sm_table1_fico_sum'] = random_values.round().astype (int)

random_values = np.random.normal(loc=13027.6,scale =1661,size=num_rows) 
random_values = np.clip(random_values,450, 754568)
df_costco_acquisition_sm_table1 ['costco_acquisition_sm_table1_fico_sum_appl'] = random_values.round().astype (int)


random_values = np.random.normal(loc=69924.1,scale =4000,size=num_rows) 
random_values = np.clip(random_values,0,7471800)
df_costco_acquisition_sm_table1 ['costco_acquisition_sm_table1_credit_limit'] = random_values.round().astype (int)


random_values = np.random.normal(loc=43694.6,scale =990,size=num_rows) 
random_values = np.clip(random_values,-22, 3020015)
df_costco_acquisition_sm_table1 ['costco_acquisition_sm_table1_tt_card_num'] = random_values.round().astype (int)

num_rows = 1000
all_yyyymm = [str(year) + str(month).zfill(2) for year in range(2016, 2024) for month in range(1, 13)]
all_yyyymm = [yyyymm for yyyymm in all_yyyymm if yyyymm <= '202309']
all_yyyymm = [yyyymm for yyyymm in all_yyyymm if yyyymm >= '201606']
ran_yyyymm = [random.choice(all_yyyymm) for _ in range(num_rows)]

# Convert yyyymm to yyyymmdd format
ran_yyyymmdd = [yyyymm + random.choice([str(day).zfill(2) for day in range(1, 29)]) for yyyymm in ran_yyyymm]

df_costco_acquisition_sm_table1['costco_acquisition_sm_table1_as_of_dt'] = ran_yyyymmdd

costco_acquisition_sm_table1_channel_detail= ['App by Phone', 'Business Center', 'Business Center Email Placements', 'Citi Branches', 'Citi Channels',
                 'Citicards.com', 'Corporate Liability', 'Costco Email Placements', 'Costco Publications - LPs',
                 'Costco Publications - Phone', 'Costco.com', 'CostcoTravel.com', 'Display', 'External Affiliates',
                 'ITA', 'Marketing Brochure & Other - LPs', 'Marketing Brochure & Other - Phone', 'Non-Partner Email',
                 'NULL', 'PA', 'Paid Search', 'Partner Phones', 'Partner Social', 'Prequal ITA', 'Prequal Pre-Approve',
                 'Purchase Path', 'Pure Digital', 'Solo Email Placements', 'Tablet']
df_costco_acquisition_sm_table1['costco_acquisition_sm_table1_channel_detail'] = np.random.choice( costco_acquisition_sm_table1_channel_detail, df_costco_acquisition_sm_table1.shape[0],
                                                                    p=[0.05,0.04,0.01,0.05,0.02,0.04,0.05,0.03,0.05,0.04,0.05,0.05,0.00,
                                                                       0.05,0.03,0.05,0.04,0.02,0.00,0.04,0.05,0.04,0.02,
                                                                       0.02,0.02,0.05,0.05,0.03,0.01]
                                                                   )
costco_acquisition_sm_table1_pera_chnl= ['CBNA Retail','Citi Digital','Citi Email_dont_in','External Affiliate','ITA','NULL','PA','Partner Digital', 'Partner Non Digtal']
df_costco_acquisition_sm_table1['costco_acquisition_sm_table1_pera_chnl'] = np.random.choice( costco_acquisition_sm_table1_pera_chnl, df_costco_acquisition_sm_table1.shape[0],
                                                                    p=[0.02,0.13,0.01,0.06,0.01,0.01,0.01,0.15,0.60]
                                                                   )



df_costco_acquisition_sm_table1
# Out:
#     costco_acquisition_sm_table1_open_time  \
# 0                                   201607
# 1                                   202109
# 2                                   201709
# 3                                   201702
# 4                                   201808
# ..                                     ...
# 995                                 202004
# 996                                 202001
# 997                                 201911
# 998                                 202210
# 999                                 202111
#
#     costco_acquisition_sm_table1_sub_channel_info  \
# 0                                       Warehouse
# 1                                       Warehouse
# 2                                       Warehouse
# 3                               Costco Collateral
# 4                                      Citi Sites
# ..                                            ...
# 995                             Costco Collateral
# ...

# %%
df_info = pd.DataFrame(columns=['column_name', 'Data_type'])
df_info['column_name'] = df_costco_acquisition_sm_table1 .columns.tolist()

for i in range(df_info.shape[0]):
    df_info.loc[i, 'Data_type'] = df_costco_acquisition_sm_table1 [df_info.loc[i, 'column_name']].dtype

df_costco_acquisition_sm_table1 .to_csv('df_costco_acquisition_sm_table1.csv', index=False)
df_info.to_csv('df_costco_acquisition_sm_table1 _info.csv', index=False)
df_info
# Out:
#                                          column_name Data_type
# 0             costco_acquisition_sm_table1_open_time    object
# 1      costco_acquisition_sm_table1_sub_channel_info    object
# 2   costco_acquisition_sm_table1_warehouse_region_cd    object
# 3              costco_acquisition_sm_table1_portf_id    object
# 4       costco_acquisition_sm_table1_membership_type    object
# 5       costco_acquisition_sm_table1_membership_role    object
# 6             costco_acquisition_sm_table1_fico_band    object
# 7               costco_acquisition_sm_table1_tt_card    object
# 8             costco_acquisition_sm_table1_p_m_1year     int64
# 9              costco_acquisition_sm_table1_trip_dub    object
# 10    costco_acquisition_sm_table1_credit_line_range    object
# 11         costco_acquisition_sm_table1_approved_tag     int64
# 12         costco_acquisition_sm_table1_applications     int64
# 13             costco_acquisition_sm_table1_approved     int64
# ...

# %% [markdown]
# **costco_acquisitions_sm_table2**

# %%
 import pandas as pd
import numpy as np
import random

df_costco_acquisitions_sm_table2 = pd.DataFrame(columns=[
    'costco_acquisitions_sm_table2_open_time',
    'costco_acquisitions_sm_table2_dimension',
    'costco_acquisitions_sm_table2_sub_dimension',
    'costco_acquisitions_sm_table2_applications',
    'costco_acquisitions_sm_table2_applications_approved',
    'costco_acquisitions_sm_table2_sum_credit_limit'
])

num_rows = 1000
all_yyyymm = [str(year) + str(month).zfill(2) for year in range(2016, 2024) for month in range(1, 13)]
all_yyyymm = [yyyymm for yyyymm in all_yyyymm if yyyymm <= '202309']
all_yyyymm = [yyyymm for yyyymm in all_yyyymm if yyyymm >= '201606']
ran_yyyymm = [random.choice(all_yyyymm) for _ in range(num_rows)]
df_costco_acquisitions_sm_table2['costco_acquisitions_sm_table2_open_time'] = ran_yyyymm
df_costco_acquisitions_sm_table2['costco_acquisitions_sm_table2_dimension'] = 'channel_detail'
costco_acquisitions_sm_table2_sub_dimension = ['App by Phone', 'Business Center', 'Business Center Email Placements', 'Citi Branches', 'Citi Channels',
                 'Citicards.com', 'Corporate Liability', 'Costco Email Placements', 'Costco Publications - LPs',
                 'Costco Publications - Phone', 'Costco.com', 'CostcoTravel.com', 'Display', 'External Affiliates',
                 'ITA', 'Marketing Brochure & Other - LPs', 'Marketing Brochure & Other - Phone', 'Non-Partner Email',
                 'NULL', 'PA', 'Paid Search', 'Partner Phones', 'Partner Social', 'Prequal ITA', 'Prequal Pre-Approve',
                 'Purchase Path', 'Pure Digital', 'Solo Email Placements', 'Tablet']
df_costco_acquisitions_sm_table2['costco_acquisitions_sm_table2_sub_dimension'] = np.random.choice(costco_acquisitions_sm_table2_sub_dimension, df_costco_acquisitions_sm_table2.shape[0],
                                                                    p=[0.05,0.04,0.01,0.05,0.02,0.04,0.05,0.03,0.05,0.04,0.05,0.05,0.00,
                                                                       0.05,0.03,0.05,0.04,0.02,0.00,0.04,0.05,0.04,0.02,
                                                                       0.02,0.02,0.05,0.05,0.03,0.01]
                                                                   )  # Specify the remaining probabilities
random_values = np.random.normal(loc=4.1,scale=481.5, size=num_rows) 
random_values = np.clip(random_values,1.0, 182311)
df_costco_acquisitions_sm_table2 ['costco_acquisitions_sm_table2_applications'] = random_values.round().astype (int)


random_values = np.random.normal(loc=2.3,scale=269.5, size=num_rows) 
random_values = np.clip(random_values,0, 130588)
df_costco_acquisitions_sm_table2 ['costco_acquisitions_sm_table2_applications_approved'] = random_values.round().astype (int)

random_values = np.random.normal(loc=18038952,scale=2193550, size=num_rows) 
random_values = np.clip(random_values,0, 1110273100)
df_costco_acquisitions_sm_table2 ['costco_acquisitions_sm_table2_sum_credit_limit'] = random_values.round().astype (int)

df_costco_acquisitions_sm_table2
# Out:
#     costco_acquisitions_sm_table2_open_time  \
# 0                                    201807
# 1                                    201707
# 2                                    202308
# 3                                    202111
# 4                                    201706
# ..                                      ...
# 995                                  201711
# 996                                  202111
# 997                                  201712
# 998                                  201906
# 999                                  202201
#
#     costco_acquisitions_sm_table2_dimension  \
# 0                            channel_detail
# 1                            channel_detail
# 2                            channel_detail
# 3                            channel_detail
# 4                            channel_detail
# ..                                      ...
# 995                          channel_detail
# 996                          channel_detail
# ...

# %%
df_info = pd.DataFrame(columns=['column_name', 'Data_type'])
df_info['column_name'] = df_costco_acquisitions_sm_table2.columns.tolist()

for i in range(df_info.shape[0]):
    df_info.loc[i, 'Data_type'] =df_costco_acquisitions_sm_table2[df_info.loc[i, 'column_name']].dtype

df_costco_acquisitions_sm_table2.to_csv('df_costco_acquisitions_sm_table2.csv', index=False)
df_info.to_csv('df_costco_acquisitions_sm_table2_info.csv', index=False)
df_info
# Out:
#                                          column_name Data_type
# 0            costco_acquisitions_sm_table2_open_time    object
# 1            costco_acquisitions_sm_table2_dimension    object
# 2        costco_acquisitions_sm_table2_sub_dimension    object
# 3         costco_acquisitions_sm_table2_applications     int64
# 4  costco_acquisitions_sm_table2_applications_app...     int64
# 5     costco_acquisitions_sm_table2_sum_credit_limit     int64

# %% [markdown]
# **costco_acquisitions_sm_daily_table3**

# %%
import pandas as pd
import numpy as np
from datetime import datetime
import random

num_rows = 1000

df_costco_acquisitions_sm_daily_table3 = pd.DataFrame(columns=[
    'costco_acquisitions_sm_daily_table3_1st_dcsn_dt',
    'costco_acquisitions_sm_daily_table3_sub_channel_info',
    'costco_acquisitions_sm_daily_table3_warehouse_region_cd',
    'costco_acquisitions_sm_daily_table3_portf_id',
    'costco_acquisitions_sm_daily_table3_membership_type',
    'costco_acquisitions_sm_daily_table3_membership_role',
    'costco_acquisitions_sm_daily_table3_fico_band',
    'costco_acquisitions_sm_daily_table3_tt_card',
    'costco_acquisitions_sm_daily_table3_p_m_1year',
    'costco_acquisitions_sm_daily_table3_trip_dub',
    'costco_acquisitions_sm_daily_table3_credit_line_range',
    'costco_acquisitions_sm_daily_table3_approved_tag',
    'costco_acquisitions_sm_daily_table3_applications',
    'costco_acquisitions_sm_daily_table3_approved',
    'costco_acquisitions_sm_daily_table3_fico_sum',
    'costco_acquisitions_sm_daily_table3_credit_limit',
    'costco_acquisitions_sm_daily_table3_tt_card_num',
    'costco_acquisitions_sm_daily_table3_as_of_dt',
    'costco_acquisitions_sm_daily_table3_channel_detail',
    'costco_acquisitions_sm_daily_table3_pera_chnl'
])

idx = pd.date_range(start='2018-01-31', end='2023-08-31', freq='D')
df_costco_acquisitions_sm_daily_table3['costco_acquisitions_sm_daily_table3_1st_dcsn_dt'] = idx
df_costco_acquisitions_sm_daily_table3['costco_acquisitions_sm_daily_table3_1st_dcsn_dt'] = df_costco_acquisitions_sm_daily_table3['costco_acquisitions_sm_daily_table3_1st_dcsn_dt'].apply(lambda x: datetime.strptime(str(x)[:10], '%Y-%m-%d').strftime('%d%b%Y'))

costco_acquisitions_sm_daily_table3_sub_channel_info = ['Citi Email','Citi Retail','Citi Sites','Costco Collateral','Costco Email',
                    'Costco Sites','External Sites','ITA','NULL','PA','Warehouse']
df_costco_acquisitions_sm_daily_table3['costco_acquisitions_sm_daily_table3_sub_channel_info'] = np.random.choice(costco_acquisitions_sm_daily_table3_sub_channel_info, df_costco_acquisitions_sm_daily_table3.shape[0],p=[0.00,0.02,0.12,0.06,0.01,0.13,0.08,0.01,0.00,0.01,0.56])

costco_acquisitions_sm_daily_table3_warehouse_region_cd = ['-','BA','BD','LA','MW',
                    'NE','NULL','NW','SD','SE','TE']
df_costco_acquisitions_sm_daily_table3['costco_acquisitions_sm_daily_table3_warehouse_region_cd'] = np.random.choice(costco_acquisitions_sm_daily_table3_warehouse_region_cd, df_costco_acquisitions_sm_daily_table3.shape[0],p=[0.43,0.07,0.03,0.07,0.07,0.06,0.03,0.07,0.07,0.06,0.04])

costco_acquisitions_sm_daily_table3_portf_id = ['520','521','522']
df_costco_acquisitions_sm_daily_table3['costco_acquisitions_sm_daily_table3_portf_id'] = np.random.choice(costco_acquisitions_sm_daily_table3_portf_id, df_costco_acquisitions_sm_daily_table3.shape[0],p=[0.65,0.13,0.22])

costco_acquisitions_sm_daily_table3_membership_type = ['B','E','G','o']
df_costco_acquisitions_sm_daily_table3['costco_acquisitions_sm_daily_table3_membership_type'] = np.random.choice(costco_acquisitions_sm_daily_table3_membership_type, df_costco_acquisitions_sm_daily_table3.shape[0],p=[0.35,0.07,0.56,0.02])

costco_acquisitions_sm_daily_table3_membership_role = ['0','1']
df_costco_acquisitions_sm_daily_table3['costco_acquisitions_sm_daily_table3_membership_role'] = np.random.choice(costco_acquisitions_sm_daily_table3_membership_role, df_costco_acquisitions_sm_daily_table3.shape[0],p=[0.35,0.65])

costco_acquisitions_sm_daily_table3_fico_band = ["<600", "600-629","630-659","660-699","700-749","750-799", "800-849","850","Invalid","Null"]
df_costco_acquisitions_sm_daily_table3['costco_acquisitions_sm_daily_table3_fico_band'] = np.random.choice(costco_acquisitions_sm_daily_table3_fico_band, df_costco_acquisitions_sm_daily_table3.shape[0],p=[0.05,0.07,0.10,0.12,0.15,0.18,0.17,0.10,0.03,0.03])


costco_acquisitions_sm_daily_table3_tt_card = ["SameDay","1_30Days","31_365days","365_PlusDays","X_INV"]
df_costco_acquisitions_sm_daily_table3['costco_acquisitions_sm_daily_table3_tt_card'] = np.random.choice(costco_acquisitions_sm_daily_table3_tt_card, df_costco_acquisitions_sm_daily_table3.shape[0],p=[0.19,0.12,0.20,0.47,0.02])


costco_acquisitions_sm_daily_table3_p_m_1year= [0,1,-2]
df_costco_acquisitions_sm_daily_table3['costco_acquisitions_sm_daily_table3_p_m_1year'] = np.random.choice(costco_acquisitions_sm_daily_table3_p_m_1year, df_costco_acquisitions_sm_daily_table3.shape[0],p=[0.47,0.51,0.02])


costco_acquisitions_sm_daily_table3_trip_dub= ["DoublePlay","Exec","Goldstar","NoMbrdate","TriplePlay"]
df_costco_acquisitions_sm_daily_table3['costco_acquisitions_sm_daily_table3_trip_dub'] = np.random.choice(costco_acquisitions_sm_daily_table3_trip_dub, df_costco_acquisitions_sm_daily_table3.shape[0],p=[0.06,0.50,0.31,0.00,0.13])


costco_acquisitions_sm_daily_table3_credit_line_range= ["-4","LT_2.9K","3K-3.9K","4K-9.9K","10K-11K","12K_PLus"]
df_costco_acquisitions_sm_daily_table3['costco_acquisitions_sm_daily_table3_credit_line_range'] = np.random.choice(costco_acquisitions_sm_daily_table3_credit_line_range, df_costco_acquisitions_sm_daily_table3.shape[0],p=[0.41,0.07,0.03,0.29,0.10,0.10])



random_values = np.random.normal(loc=17.7, scale=2, size=len(df_costco_acquisitions_sm_daily_table3))
random_values = np.clip(random_values, 1, 1068)
df_costco_acquisitions_sm_daily_table3['costco_acquisitions_sm_daily_table3_applications'] = random_values.round().astype(int)

random_values = np.random.normal(loc=9.68, scale=1, size=len(df_costco_acquisitions_sm_daily_table3))
random_values = np.clip(random_values, 1, 1040)
df_costco_acquisitions_sm_daily_table3['costco_acquisitions_sm_daily_table3_approved'] = random_values.round().astype(int)

df_costco_acquisitions_sm_daily_table3['costco_acquisitions_sm_daily_table3_approved_tag'] = df_costco_acquisitions_sm_daily_table3['costco_acquisitions_sm_daily_table3_approved'].map(lambda x: 1 if x != 0 else 0)

random_values = np.random.normal(loc=7348, scale=753.5, size=len(df_costco_acquisitions_sm_daily_table3))
random_values = np.clip(random_values, 0, 754568)
df_costco_acquisitions_sm_daily_table3['costco_acquisitions_sm_daily_table3_fico_sum'] = random_values.round().astype(int)


random_values = np.random.normal(loc=69924.1, scale=4000, size=len(df_costco_acquisitions_sm_daily_table3))
random_values = np.clip(random_values, 0, 7471800)
df_costco_acquisitions_sm_daily_table3['costco_acquisitions_sm_daily_table3_credit_limit'] = random_values.round().astype(int)

random_values = np.random.normal(loc=43694.6, scale=990, size=len(df_costco_acquisitions_sm_daily_table3))
random_values = np.clip(random_values, -22, 3020015)
df_costco_acquisitions_sm_daily_table3['costco_acquisitions_sm_daily_table3_tt_card_num'] = random_values.round().astype(int)

all_yyyymm = [str(year) + str(month).zfill(2) for year in range(2016, 2024) for month in range(1, 13)]
all_yyyymm = [yyyymm for yyyymm in all_yyyymm if yyyymm <= '202309']
all_yyyymm = [yyyymm for yyyymm in all_yyyymm if yyyymm >= '201606']
ran_yyyymm = [random.choice(all_yyyymm) for _ in range(len(df_costco_acquisitions_sm_daily_table3))]

# Convert yyyymm to yyyymmdd format
ran_yyyymmdd = [yyyymm + random.choice([str(day).zfill(2) for day in range(1, 29)]) for yyyymm in ran_yyyymm]

df_costco_acquisitions_sm_daily_table3['costco_acquisitions_sm_daily_table3_as_of_dt'] = ran_yyyymmdd

costco_acquisitions_sm_daily_table3_channel_detail= ['App by Phone', 'Business Center', 'Business Center Email Placements', 'Citi Branches', 'Citi Channels',
                 'Citicards.com', 'Corporate Liability', 'Costco Email Placements', 'Costco Publications - LPs',
                 'Costco Publications - Phone', 'Costco.com', 'CostcoTravel.com', 'Display', 'External Affiliates',
                 'ITA', 'Marketing Brochure & Other - LPs', 'Marketing Brochure & Other - Phone', 'Non-Partner Email',
                 'NULL', 'PA', 'Paid Search', 'Partner Phones', 'Partner Social', 'Prequal ITA', 'Prequal Pre-Approve',
                 'Purchase Path', 'Pure Digital', 'Solo Email Placements', 'Tablet']
df_costco_acquisitions_sm_daily_table3['costco_acquisitions_sm_daily_table3_channel_detail'] = np.random.choice(costco_acquisitions_sm_daily_table3_channel_detail, df_costco_acquisitions_sm_daily_table3.shape[0],
                                                                    p=[0.05,0.04,0.01,0.05,0.02,0.04,0.05,0.03,0.05,0.04,0.05,0.05,0.00,
                                                                       0.05,0.03,0.05,0.04,0.02,0.00,0.04,0.05,0.04,0.02,
                                                                       0.02,0.02,0.05,0.05,0.03,0.01]
                                                                   )
costco_acquisitions_sm_daily_table3_pera_chnl= ['CBNA Retail','Citi Digital','Citi Email_dont_in','External Affiliate','ITA','NULL','PA','Partner Digital', 'Partner Non Digtal']
df_costco_acquisitions_sm_daily_table3['costco_acquisitions_sm_daily_table3_pera_chnl'] = np.random.choice(costco_acquisitions_sm_daily_table3_pera_chnl, df_costco_acquisitions_sm_daily_table3.shape[0],
                                                                    p=[0.02,0.13,0.01,0.06,0.01,0.01,0.01,0.15,0.60]
                                                                   )



df_costco_acquisitions_sm_daily_table3
# Out:
#      costco_acquisitions_sm_daily_table3_1st_dcsn_dt  \
# 0                                          31Jan2018
# 1                                          01Feb2018
# 2                                          02Feb2018
# 3                                          03Feb2018
# 4                                          04Feb2018
# ...                                              ...
# 2034                                       27Aug2023
# 2035                                       28Aug2023
# 2036                                       29Aug2023
# 2037                                       30Aug2023
# 2038                                       31Aug2023
#
#      costco_acquisitions_sm_daily_table3_sub_channel_info  \
# 0                                            Citi Sites
# 1                                     Costco Collateral
# 2                                        External Sites
# 3                                            Citi Sites
# ...

# %%
df_info = pd.DataFrame(columns=['column_name', 'Data_type'])
df_info['column_name'] =df_costco_acquisitions_sm_daily_table3.columns.tolist()

for i in range(df_info.shape[0]):
    df_info.loc[i, 'Data_type'] = df_costco_acquisitions_sm_daily_table3[df_info.loc[i, 'column_name']].dtype

df_costco_acquisitions_sm_daily_table3.to_csv('df_costco_acquisitions_sm_daily_table3.csv', index=False)
df_info.to_csv('df_costco_acquisitions_sm_daily_table3_info.csv', index=False)
df_info
# Out:
#                                           column_name Data_type
# 0     costco_acquisitions_sm_daily_table3_1st_dcsn_dt    object
# 1   costco_acquisitions_sm_daily_table3_sub_channe...    object
# 2   costco_acquisitions_sm_daily_table3_warehouse_...    object
# 3        costco_acquisitions_sm_daily_table3_portf_id    object
# 4   costco_acquisitions_sm_daily_table3_membership...    object
# 5   costco_acquisitions_sm_daily_table3_membership...    object
# 6       costco_acquisitions_sm_daily_table3_fico_band    object
# 7         costco_acquisitions_sm_daily_table3_tt_card    object
# 8       costco_acquisitions_sm_daily_table3_p_m_1year     int64
# 9        costco_acquisitions_sm_daily_table3_trip_dub    object
# 10  costco_acquisitions_sm_daily_table3_credit_lin...    object
# 11   costco_acquisitions_sm_daily_table3_approved_tag     int64
# 12   costco_acquisitions_sm_daily_table3_applications     int64
# 13       costco_acquisitions_sm_daily_table3_approved     int64
# ...

# %% [markdown]
# **costco_acquisitions_sm_sankey_table4**

# %%
import pandas as pd
import numpy as np
import random

num_rows = 1000

df_costco_acquisitions_sm_sankey_table4  = pd.DataFrame(columns=[
    'costco_acquisitions_sm_sankey_table4_open_time',
    'costco_acquisitions_sm_sankey_table4_sub_channel_info',
    'costco_acquisitions_sm_sankey_table4_warehouse_region_cd',
    'costco_acquisitions_sm_sankey_table4_portf_id',
    'costco_acquisitions_sm_sankey_table4_membership_type',
    'costco_acquisitions_sm_sankey_table4_membership_role',
    'costco_acquisitions_sm_sankey_table4_fico_band',
    'costco_acquisitions_sm_sankey_table4_tt_card',
    'costco_acquisitions_sm_sankey_table4_p_m_1year',
    'costco_acquisitions_sm_sankey_table4_trip_dub',
    'costco_acquisitions_sm_sankey_table4_credit_line_range',
    'costco_acquisitions_sm_sankey_table4_approved_tag',
    'costco_acquisitions_sm_sankey_table4_applications',
    'costco_acquisitions_sm_sankey_table4_approved',
    'costco_acquisitions_sm_sankey_table4_fico_sum',
    'costco_acquisitions_sm_sankey_table4_fico_sum_appl',
    'costco_acquisitions_sm_sankey_table4_credit_limit',
    'costco_acquisitions_sm_sankey_table4_tt_card_num',
    'costco_acquisitions_sm_sankey_table4_as_of_dt',
    'costco_acquisitions_sm_sankey_table4_channel_detail',
    'costco_acquisitions_sm_sankey_table4_pera_chnl',
    'costco_acquisitions_sm_sankey_table4_link'
])



all_yyyymm = [str(year) + str(month).zfill(2) for year in range(2016, 2024) for month in range(1, 13)]
all_yyyymm = [yyyymm for yyyymm in all_yyyymm if yyyymm <= '202309']
all_yyyymm = [yyyymm for yyyymm in all_yyyymm if yyyymm >= '201606']
ran_yyyymm = [random.choice(all_yyyymm) for _ in range(num_rows)]
df_costco_acquisitions_sm_sankey_table4['costco_acquisitions_sm_sankey_table4_open_time'] = ran_yyyymm

costco_acquisitions_sm_sankey_table4_sub_channel_info = ['Citi Email','Citi Retail','Citi Sites','Costco Collateral','Costco Email',
                    'Costco Sites','External Sites','ITA','NULL','PA','Warehouse']
df_costco_acquisitions_sm_sankey_table4['costco_acquisitions_sm_sankey_table4_sub_channel_info'] = np.random.choice(costco_acquisitions_sm_sankey_table4_sub_channel_info, df_costco_acquisitions_sm_sankey_table4.shape[0],p=[0.00,0.02,0.12,0.06,0.01,0.13,0.08,0.01,0.00,0.01,0.56])


costco_acquisitions_sm_sankey_table4_warehouse_region_cd = ['-','BA','BD','LA','MW',
                    'NE','NULL','NW','SD','SE','TE']
df_costco_acquisitions_sm_sankey_table4['costco_acquisitions_sm_sankey_table4_warehouse_region_cd'] = np.random.choice(costco_acquisitions_sm_sankey_table4_warehouse_region_cd, df_costco_acquisitions_sm_sankey_table4.shape[0],p=[0.43,0.07,0.03,0.07,0.07,0.06,0.03,0.07,0.07,0.06,0.04])

costco_acquisitions_sm_sankey_table4_portf_id = ['520','521','522']
df_costco_acquisitions_sm_sankey_table4['costco_acquisitions_sm_sankey_table4_portf_id'] = np.random.choice(costco_acquisitions_sm_sankey_table4_portf_id, df_costco_acquisitions_sm_sankey_table4.shape[0],p=[0.65,0.13,0.22])

costco_acquisitions_sm_sankey_table4_membership_type = ['B','E','G','o']
df_costco_acquisitions_sm_sankey_table4['costco_acquisitions_sm_sankey_table4_membership_type'] = np.random.choice(costco_acquisitions_sm_sankey_table4_membership_type, df_costco_acquisitions_sm_sankey_table4.shape[0],p=[0.35,0.07,0.56,0.02])

costco_acquisitions_sm_sankey_table4_membership_role = ['0','1']
df_costco_acquisitions_sm_sankey_table4['costco_acquisitions_sm_sankey_table4_membership_role'] = np.random.choice(costco_acquisitions_sm_sankey_table4_membership_role, df_costco_acquisitions_sm_sankey_table4.shape[0],p=[0.35,0.65])

costco_acquisitions_sm_sankey_table4_fico_band = ["<600", "600-629","630-659","660-699","700-749","750-799", "800-849","850","Invalid","Null"]
df_costco_acquisitions_sm_sankey_table4['costco_acquisitions_sm_sankey_table4_fico_band'] = np.random.choice(costco_acquisitions_sm_sankey_table4_fico_band, df_costco_acquisitions_sm_sankey_table4.shape[0],p=[0.05,0.07,0.10,0.12,0.15,0.18,0.17,0.10,0.03,0.03])


costco_acquisitions_sm_sankey_table4_tt_card = ["SameDay","1_30Days","31_365days","365_PlusDays","X_INV"]
df_costco_acquisitions_sm_sankey_table4['costco_acquisitions_sm_sankey_table4_tt_card'] = np.random.choice(costco_acquisitions_sm_sankey_table4_tt_card, df_costco_acquisitions_sm_sankey_table4.shape[0],p=[0.19,0.12,0.20,0.47,0.02])


costco_acquisitions_sm_sankey_table4_p_m_1year= [0,1,-2]
df_costco_acquisitions_sm_sankey_table4['costco_acquisitions_sm_sankey_table4_p_m_1year'] = np.random.choice(costco_acquisitions_sm_sankey_table4_p_m_1year, df_costco_acquisitions_sm_sankey_table4.shape[0],p=[0.47,0.51,0.02])


costco_acquisitions_sm_sankey_table4_trip_dub= ["DoublePlay","Exec","Goldstar","NoMbrdate","TriplePlay"]
df_costco_acquisitions_sm_sankey_table4['costco_acquisitions_sm_sankey_table4_trip_dub'] = np.random.choice(costco_acquisitions_sm_sankey_table4_trip_dub, df_costco_acquisitions_sm_sankey_table4.shape[0],p=[0.06,0.50,0.31,0.00,0.13])


costco_acquisitions_sm_sankey_table4_credit_line_range= ["-4","LT_2.9K","3K-3.9K","4K-9.9K","10K-11K","12K_PLus"]
df_costco_acquisitions_sm_sankey_table4['costco_acquisitions_sm_sankey_table4_credit_line_range'] = np.random.choice(costco_acquisitions_sm_sankey_table4_credit_line_range, df_costco_acquisitions_sm_sankey_table4.shape[0],p=[0.41,0.07,0.03,0.29,0.10,0.10])



random_values = np.random.normal(loc=17.7, scale=2, size=num_rows)
random_values = np.clip(random_values, 1, 1068)
df_costco_acquisitions_sm_sankey_table4['costco_acquisitions_sm_sankey_table4_applications'] = random_values.round().astype(int)

random_values = np.random.normal(loc=9.68, scale=1, size=num_rows)
random_values = np.clip(random_values, 1, 1040)
df_costco_acquisitions_sm_sankey_table4['costco_acquisitions_sm_sankey_table4_approved'] = random_values.round().astype(int)

df_costco_acquisitions_sm_sankey_table4['costco_acquisitions_sm_sankey_table4_approved_tag'] = df_costco_acquisitions_sm_sankey_table4['costco_acquisitions_sm_sankey_table4_approved'].map(lambda x: 1 if x != 0 else 0)

random_values = np.random.normal(loc=7348, scale=753.5, size=num_rows)
random_values = np.clip(random_values, 0, 754568)
df_costco_acquisitions_sm_sankey_table4['costco_acquisitions_sm_sankey_table4_fico_sum'] = random_values.round().astype(int)

random_values = np.random.normal(loc=13027.6, scale=1661, size=num_rows)
random_values = np.clip(random_values, 450, 754568)
df_costco_acquisitions_sm_sankey_table4['costco_acquisitions_sm_sankey_table4_fico_sum_appl'] = random_values.round().astype(int)

random_values = np.random.normal(loc=69924.1, scale=4000, size=num_rows)
random_values = np.clip(random_values, 0, 7471800)
df_costco_acquisitions_sm_sankey_table4['costco_acquisitions_sm_sankey_table4_credit_limit'] = random_values.round().astype(int)

random_values = np.random.normal(loc=43694.6, scale=990, size=num_rows)
random_values = np.clip(random_values, -22, 3020015)
df_costco_acquisitions_sm_sankey_table4['costco_acquisitions_sm_sankey_table4_tt_card_num'] = random_values.round().astype(int)

all_yyyymm = [str(year) + str(month).zfill(2) for year in range(2016, 2024) for month in range(1, 13)]
all_yyyymm = [yyyymm for yyyymm in all_yyyymm if yyyymm <= '202309']
all_yyyymm = [yyyymm for yyyymm in all_yyyymm if yyyymm >= '201606']
ran_yyyymm = [random.choice(all_yyyymm) for _ in range(num_rows)]

# Convert yyyymm to yyyymmdd format
ran_yyyymmdd = [yyyymm + random.choice([str(day).zfill(2) for day in range(1, 29)]) for yyyymm in ran_yyyymm]

df_costco_acquisitions_sm_sankey_table4['costco_acquisitions_sm_sankey_table4_as_of_dt'] = ran_yyyymmdd

costco_acquisitions_sm_sankey_table4_channel_detail= ['App by Phone', 'Business Center', 'Business Center Email Placements', 'Citi Branches', 'Citi Channels',
                 'Citicards.com', 'Corporate Liability', 'Costco Email Placements', 'Costco Publications - LPs',
                 'Costco Publications - Phone', 'Costco.com', 'CostcoTravel.com', 'Display', 'External Affiliates',
                 'ITA', 'Marketing Brochure & Other - LPs', 'Marketing Brochure & Other - Phone', 'Non-Partner Email',
                 'NULL', 'PA', 'Paid Search', 'Partner Phones', 'Partner Social', 'Prequal ITA', 'Prequal Pre-Approve',
                 'Purchase Path', 'Pure Digital', 'Solo Email Placements', 'Tablet']
df_costco_acquisitions_sm_sankey_table4['costco_acquisitions_sm_sankey_table4_channel_detail'] = np.random.choice(costco_acquisitions_sm_sankey_table4_channel_detail, df_costco_acquisitions_sm_sankey_table4.shape[0],
                                                                    p=[0.05,0.04,0.01,0.05,0.02,0.04,0.05,0.03,0.05,0.04,0.05,0.05,0.00,
                                                                       0.05,0.03,0.05,0.04,0.02,0.00,0.04,0.05,0.04,0.02,
                                                                       0.02,0.02,0.05,0.05,0.03,0.01]
                                                                   )
costco_acquisitions_sm_sankey_table4_pera_chnl= ['CBNA Retail','Citi Digital','Citi Email_dont_in','External Affiliate','ITA','NULL','PA','Partner Digital', 'Partner Non Digtal']
df_costco_acquisitions_sm_sankey_table4['costco_acquisitions_sm_sankey_table4_pera_chnl'] = np.random.choice(costco_acquisitions_sm_sankey_table4_pera_chnl, df_costco_acquisitions_sm_sankey_table4.shape[0],
                                                                    p=[0.02,0.13,0.01,0.06,0.01,0.01,0.01,0.15,0.60]
                                                                   )

costco_acquisitions_sm_sankey_table4_link= ['Link'] 
df_costco_acquisitions_sm_sankey_table4['costco_acquisitions_sm_sankey_table4_link']= np.random.choice(costco_acquisitions_sm_sankey_table4_link, df_costco_acquisitions_sm_sankey_table4.shape[0],
                                                                    p=[1.0]
                                                                   )


df_costco_acquisitions_sm_sankey_table4
# Out:
#     costco_acquisitions_sm_sankey_table4_open_time  \
# 0                                           202304
# 1                                           202308
# 2                                           202308
# 3                                           202212
# 4                                           201911
# ..                                             ...
# 995                                         202202
# 996                                         201704
# 997                                         202309
# 998                                         202007
# 999                                         202209
#
#     costco_acquisitions_sm_sankey_table4_sub_channel_info  \
# 0                                            Warehouse
# 1                                           Citi Sites
# 2                                           Citi Sites
# 3                                       External Sites
# 4                                       External Sites
# ...

# %%
df_info = pd.DataFrame(columns=['column_name', 'Data_type'])
df_info['column_name'] = df_costco_acquisitions_sm_sankey_table4.columns.tolist()

for i in range(df_info.shape[0]):
    df_info.loc[i, 'Data_type'] = df_costco_acquisitions_sm_sankey_table4[df_info.loc[i, 'column_name']].dtype

df_costco_acquisitions_sm_sankey_table4.to_csv('df_costco_acquisitions_sm_sankey_table4.csv', index=False)
df_info.to_csv('df_costco_acquisitions_sm_sankey_table4_info.csv', index=False)
df_info
# Out:
#                                           column_name Data_type
# 0      costco_acquisitions_sm_sankey_table4_open_time    object
# 1   costco_acquisitions_sm_sankey_table4_sub_chann...    object
# 2   costco_acquisitions_sm_sankey_table4_warehouse...    object
# 3       costco_acquisitions_sm_sankey_table4_portf_id    object
# 4   costco_acquisitions_sm_sankey_table4_membershi...    object
# 5   costco_acquisitions_sm_sankey_table4_membershi...    object
# 6      costco_acquisitions_sm_sankey_table4_fico_band    object
# 7        costco_acquisitions_sm_sankey_table4_tt_card    object
# 8      costco_acquisitions_sm_sankey_table4_p_m_1year     int64
# 9       costco_acquisitions_sm_sankey_table4_trip_dub    object
# 10  costco_acquisitions_sm_sankey_table4_credit_li...    object
# 11  costco_acquisitions_sm_sankey_table4_approved_tag     int64
# 12  costco_acquisitions_sm_sankey_table4_applications     int64
# 13      costco_acquisitions_sm_sankey_table4_approved     int64
# ...

# %% [markdown]
# **costco_acquisitions_lm_final**

# %%
import pandas as pd
import numpy as np
import random

num_rows = 1000

df_costco_acquisitions_lm_final = pd.DataFrame(columns=[
    'per_num',
    'pid_segment',
    'vintage_month',
    'mob',
    'vintage_quarter',
    'channel_info',
    'pay_in_full_tag',
    'final_fico',
    'channel_detail',
    'pera_chnl',
    'accts',
    'accts_new_acquisitions',
    'open_accts',
    'accts_closed_new',
    'bill_actv_accts',
    'accts_active_sales',
    'accts_ncl',
    'interest_charged',
    'nim',
    'cost_of_funds',
    'ncl_dollar_amt',
    'sales_purchase',
    'purch_sales',
    'cnr',
    'ncm',
    'bi',
    'total_payment',
    'bal_anr',
    'bal_enr',
    'bal_open',
    'bal_revolving',
    'accts_enr_delq_26',
    'accts_enr_delq_36',
    'apr_weighted_avg',
    'bal_risk',
    'bal_intro',
    'bal_goto',
    'accts_enr',
    'interchange',
    'total_credit_limit',
    'a_4x_cco_gas',
    'n_4x_cco_gas',
    'a_2x_costco_wareouse',
    'n_2x_costco_wareouse',
    'a_2x_costco_online',
    'n_2x_costco_online',
    'a_3x_costco_travel',
    'n_3x_costco_travel',
    'a_2x_costco_other',
    'n_2x_costco_other',
    'a_2x_costco_mbr',
    'n_2x_costco_mbr',
    'a_4x_gas',
    'n_4x_gas',
    'a_3x_travel',
    'n_3x_travel',
    'a_3x_restaurant',
    'n_3x_restaurant',
    'a_1x_other',
    'n_1x_other',
    'a_trans_amt_online',
    'n_trans_online',
    'a_cco',
    'n_cco',
    'a_non_cco',
    'n_non_cco',
    'a_total',
    'n_total',
    'a_interchange',
    'goto_bal_revolving',
    'a_interchange',
    'goto_bal_revolving',
    'tt_card_num',
    'tt_card_accts',
    'cycle_interest_cr_amt',
    'rebate_cost',
    'sub_channel_info'
])

df_costco_acquisitions_lm_final['per_num'] = ['6454'] * 1000

df_costco_acquisitions_lm_final['pid_segment'] = ['520'] * 1000

all_yyyymm = [str(year) + str(month).zfill(2) for year in range(2022, 2023) for month in range(1, 13)]
all_yyyymm = [yyyymm for yyyymm in all_yyyymm if yyyymm <= '202309']
all_yyyymm = [yyyymm for yyyymm in all_yyyymm if yyyymm >= '201606']
ran_yyyymm = [random.choice(all_yyyymm) for _ in range(num_rows)]

df_costco_acquisitions_lm_final['vintage_month'] = ['V' + yyyymm[:6] for yyyymm in ran_yyyymm]


mob = [17,18,19,20,21,22,23,24,25]
df_costco_acquisitions_lm_final['mob'] = np.random.choice(mob,df_costco_acquisitions_lm_final.shape[0],p=[0.02,0.09,0.09,0.17,0.16,0.17,0.15,0.08,0.07])



pay_in_full_tag = [-1,0,1]
df_costco_acquisitions_lm_final['pay_in_full_tag'] = np.random.choice(pay_in_full_tag,df_costco_acquisitions_lm_final.shape[0],p=[0.31,0.33,0.36])

df_costco_acquisitions_lm_final['final_fico'] = ['NA'] * 1000

pera_chnl= ['CBNA Retail','Citi Digital','Citi Email_dont_in','External Affiliate','ITA','NULL','PA','Partner Digital', 'Partner Non Digtal']
df_costco_acquisitions_lm_final['pera_chnl'] = np.random.choice(pera_chnl, df_costco_acquisitions_lm_final.shape[0],p=[0.02,0.13,0.01,0.06,0.01,0.01,0.01,0.15,0.60])

sub_channel_info = ['Citi Email','Citi Retail','Citi Sites','Costco Collateral','Costco Email',
                    'Costco Sites','External Sites','ITA','NULL','PA','Warehouse']
df_costco_acquisitions_lm_final['sub_channel_info'] = np.random.choice(sub_channel_info, df_costco_acquisitions_lm_final.shape[0],p=[0.00,0.02,0.12,0.06,0.01,0.13,0.08,0.01,0.00,0.01,0.56])

channel_detail= ['App by Phone', 'Business Center', 'Business Center Email Placements', 'Citi Branches', 'Citi Channels',
                 'Citicards.com', 'Corporate Liability', 'Costco Email Placements', 'Costco Publications - LPs',
                 'Costco Publications - Phone', 'Costco.com', 'CostcoTravel.com', 'Display', 'External Affiliates',
                 'ITA', 'Marketing Brochure & Other - LPs', 'Marketing Brochure & Other - Phone', 'Non-Partner Email',
                 'NULL', 'PA', 'Paid Search', 'Partner Phones', 'Partner Social', 'Prequal ITA', 'Prequal Pre-Approve',
                 'Purchase Path', 'Pure Digital', 'Solo Email Placements', 'Tablet']
df_costco_acquisitions_lm_final['channel_detail'] = np.random.choice(channel_detail, df_costco_acquisitions_lm_final.shape[0],
                                                                    p=[0.05,0.04,0.01,0.05,0.02,0.04,0.05,0.03,0.05,0.04,0.05,0.05,0.00,
                                                                       0.05,0.03,0.05,0.04,0.02,0.00,0.04,0.05,0.04,0.02,
                                                                       0.02,0.02,0.05,0.05,0.03,0.01])

quarters = ['Q1', 'Q2', 'Q3', 'Q4']
df_costco_acquisitions_lm_final['vintage_quarter'] = [yyyymm[:4] + ' ' + random.choice(quarters) for yyyymm in ran_yyyymm]

df_costco_acquisitions_lm_final['channel_info'] = df_costco_acquisitions_lm_final['sub_channel_info'].map({
    'Citi Email': 'Citi Digital',
    'Citi Sites': 'Citi Digital',
    'External Sites': 'Citi Digital',
    'Citi Retail': 'Citi Retail',
    'Costco Collateral': 'Costco Collateral',
    'Costco Email': 'Costco Digital',
    'Costco Sites': 'Costco Digital',
    'PA': 'Direct Mail',
    'NULL': 'No Channel Info',
    'Warehouse': 'Warehouse'
})


random_values = np.random.normal(loc=708.8, scale=29, size=len(df_costco_acquisitions_lm_final))
random_values = np.clip(random_values, 1, 32025)
df_costco_acquisitions_lm_final['accts'] = random_values.round().astype(int)

random_values = np.random.normal(loc=0, scale=0, size=len(df_costco_acquisitions_lm_final))
random_values = np.clip(random_values,0, 0)
df_costco_acquisitions_lm_final['accts_new_acquisitions'] = random_values.round().astype(int)

random_values = np.random.normal(loc=654.5, scale=23, size=len(df_costco_acquisitions_lm_final))
random_values = np.clip(random_values,0, 31894)
df_costco_acquisitions_lm_final['open_accts'] = random_values.round().astype(int)

random_values = np.random.normal(loc=3.14, scale=0, size=len(df_costco_acquisitions_lm_final))
random_values = np.clip(random_values,0, 518)
df_costco_acquisitions_lm_final['accts_closed_new'] = random_values.round().astype(int)

random_values = np.random.normal(loc=585.3, scale=8, size=len(df_costco_acquisitions_lm_final))
random_values = np.clip(random_values,0,31948 )
df_costco_acquisitions_lm_final['bill_actv_accts'] = random_values.round().astype(int)

random_values = np.random.normal(loc=506.3, scale=7, size=len(df_costco_acquisitions_lm_final))
random_values = np.clip(random_values,0,29377 )
df_costco_acquisitions_lm_final['accts_active_sales'] = random_values.round().astype(int)

random_values = np.random.normal(loc=0.62, scale=0, size=len(df_costco_acquisitions_lm_final))
random_values = np.clip(random_values,0,56 )
df_costco_acquisitions_lm_final['accts_ncl'] = random_values.round().astype(int)

random_values = np.random.normal(loc=10550.2, scale=51.5, size=len(df_costco_acquisitions_lm_final))
random_values = np.clip(random_values,0,771446 )
df_costco_acquisitions_lm_final['interest_charged'] = random_values.round().astype(int)

random_values = np.random.normal(loc=9195.6, scale=0, size=len(df_costco_acquisitions_lm_final))
random_values = np.clip(random_values,-434,697315)
df_costco_acquisitions_lm_final['nim'] = random_values.round().astype(int)

random_values = np.random.normal(loc=1354.44, scale=14.5, size=len(df_costco_acquisitions_lm_final))
random_values = np.clip(random_values,0,74130 )
df_costco_acquisitions_lm_final['cost_of_funds'] = random_values.round().astype(int)

random_values = np.random.normal(loc=2565.17, scale=0, size=len(df_costco_acquisitions_lm_final))
random_values = np.clip(random_values,0, 242565)
df_costco_acquisitions_lm_final['ncl_dollar_amt'] = random_values.round().astype(int)

random_values = np.random.normal(loc=584942.5, scale=6540, size=len(df_costco_acquisitions_lm_final))
random_values = np.clip(random_values,0, 36571239)
df_costco_acquisitions_lm_final['sales_purchase'] = random_values.round().astype(int)

random_values = np.random.normal(loc=584942.5, scale=6540, size=len(df_costco_acquisitions_lm_final))
random_values = np.clip(random_values,0, 36571239)
df_costco_acquisitions_lm_final['purch_sales'] = random_values.round().astype(int)

random_values = np.random.normal(loc=9159.3, scale=0, size=len(df_costco_acquisitions_lm_final))
random_values = np.clip(random_values,-28361,726255 )
df_costco_acquisitions_lm_final['cnr'] = random_values.round().astype(int)

random_values = np.random.normal(loc=6909.2, scale=0, size=len(df_costco_acquisitions_lm_final))
random_values = np.clip(random_values,-28361,558215)
df_costco_acquisitions_lm_final['ncm'] = random_values.round().astype(int)

random_values = np.random.normal(loc=5046.5, scale=0, size=len(df_costco_acquisitions_lm_final))
random_values = np.clip(random_values,-123426,501001)
df_costco_acquisitions_lm_final['bi'] = random_values.round().astype(int)


random_values = np.random.normal(loc=646093.1, scale=7618.5, size=len(df_costco_acquisitions_lm_final))
random_values = np.clip(random_values,0, 41591701)
df_costco_acquisitions_lm_final['total_payment',] = random_values.round().astype(int)

random_values = np.random.normal(loc=1161998.2, scale=1, size=len(df_costco_acquisitions_lm_final))
random_values = np.clip(random_values,-107,61996157)
df_costco_acquisitions_lm_final['bal_anr',] = random_values.round().astype(int)

random_values = np.random.normal(loc=1161428.6, scale=12696, size=len(df_costco_acquisitions_lm_final))
random_values = np.clip(random_values,-90,63865845 )
df_costco_acquisitions_lm_final['bal_enr',] = random_values.round().astype(int)

random_values = np.random.normal(loc=1208599, scale=13233, size=len(df_costco_acquisitions_lm_final))
random_values = np.clip(random_values,-266,63271797)
df_costco_acquisitions_lm_final['bal_open',] = random_values.round().astype(int)


random_values = np.random.normal(loc=841472.2, scale=4138.5, size=len(df_costco_acquisitions_lm_final))
random_values = np.clip(random_values,-13 ,61859173 )
df_costco_acquisitions_lm_final['bal_revolving',] = random_values.round().astype(int)

random_values = np.random.normal(loc=3.8, scale=0, size=len(df_costco_acquisitions_lm_final))
random_values = np.clip(random_values, 0,379 )
df_costco_acquisitions_lm_final['accts_enr_delq_26',] = random_values.round().astype(int)

random_values = np.random.normal(loc=2.6, scale=0, size=len(df_costco_acquisitions_lm_final))
random_values = np.clip(random_values,0 , 279)
df_costco_acquisitions_lm_final['accts_enr_delq_36',] = random_values.round().astype(int)

random_values = np.random.normal(loc=8241.4, scale=106, size=len(df_costco_acquisitions_lm_final))
random_values = np.clip(random_values, 0,415656 )
df_costco_acquisitions_lm_final['apr_weighted_avg',] = random_values.round().astype(int)

random_values = np.random.normal(loc=20575.1, scale=0, size=len(df_costco_acquisitions_lm_final))
random_values = np.clip(random_values,-239 ,1660252 )
df_costco_acquisitions_lm_final['bal_risk',] = random_values.round().astype(int)

random_values = np.random.normal(loc=494.2, scale=0, size=len(df_costco_acquisitions_lm_final))
random_values = np.clip(random_values, 0, 66925)
df_costco_acquisitions_lm_final['bal_intro',] = random_values.round().astype(int)

random_values = np.random.normal(loc=1116831.1, scale=12531, size=len(df_costco_acquisitions_lm_final))
random_values = np.clip(random_values,-90 ,61121536 )
df_costco_acquisitions_lm_final['bal_goto',] = random_values.round().astype(int)

random_values = np.random.normal(loc=703.7, scale=28, size=len(df_costco_acquisitions_lm_final))
random_values = np.clip(random_values,1 ,32022 )
df_costco_acquisitions_lm_final['accts_enr',] = random_values.round().astype(int)

random_values = np.random.normal(loc=8982.5, scale=89.5, size=len(df_costco_acquisitions_lm_final))
random_values = np.clip(random_values, -8,551955 )
df_costco_acquisitions_lm_final['interchange',] = random_values.round().astype(int)

random_values = np.random.normal(loc=6302284.4, scale=252550, size=len(df_costco_acquisitions_lm_final))
random_values = np.clip(random_values, 4000,292075900 )
df_costco_acquisitions_lm_final['total_credit_limit',] = random_values.round().astype(int)


random_values = np.random.normal(loc=18012.3, scale=218.5, size=len(df_costco_acquisitions_lm_final))
random_values = np.clip(random_values, 0, 1166202)
df_costco_acquisitions_lm_final['a_4x_cco_gas',] = random_values.round().astype(int)

random_values = np.random.normal(loc=585.0, scale=7, size=len(df_costco_acquisitions_lm_final))
random_values = np.clip(random_values,0 ,38710 )
df_costco_acquisitions_lm_final['n_4x_cco_gas',] = random_values.round().astype(int)

random_values = np.random.normal(loc=111145.9, scale=1155.5, size=len(df_costco_acquisitions_lm_final))
random_values = np.clip(random_values, -488, 7491639)
df_costco_acquisitions_lm_final['a_2x_costco_wareouse',] = random_values.round().astype(int)

random_values = np.random.normal(loc=855.5, scale=10, size=len(df_costco_acquisitions_lm_final))
random_values = np.clip(random_values, 0,58160 )
df_costco_acquisitions_lm_final['n_2x_costco_wareouse',] = random_values.round().astype(int)

random_values = np.random.normal(loc=19568.6, scale=26.5, size=len(df_costco_acquisitions_lm_final))
random_values = np.clip(random_values,-1343 ,1185296 )
df_costco_acquisitions_lm_final['a_2x_costco_online',] = random_values.round().astype(int)

random_values = np.random.normal(loc=103.1, scale=1, size=len(df_costco_acquisitions_lm_final))
random_values = np.clip(random_values,0 ,5955 )
df_costco_acquisitions_lm_final['n_2x_costco_online',] = random_values.round().astype(int)

random_values = np.random.normal(loc=923.9, scale=0, size=len(df_costco_acquisitions_lm_final))
random_values = np.clip(random_values,-5125 , 78216)
df_costco_acquisitions_lm_final['a_3x_costco_travel',] = random_values.round().astype(int) 


random_values = np.random.normal(loc=0.64, scale=0, size=len(df_costco_acquisitions_lm_final))
random_values = np.clip(random_values,0 , 41)
df_costco_acquisitions_lm_final['n_3x_costco_travel',] = random_values.round().astype(int)

random_values = np.random.normal(loc=0, scale=0, size=len(df_costco_acquisitions_lm_final))
random_values = np.clip(random_values,0 ,0 )
df_costco_acquisitions_lm_final['a_2x_costco_other',] = random_values.round().astype(int)

random_values = np.random.normal(loc=0, scale=0, size=len(df_costco_acquisitions_lm_final))
random_values = np.clip(random_values,0 , 0)
df_costco_acquisitions_lm_final['n_2x_costco_other',] = random_values.round().astype(int)

random_values = np.random.normal(loc=4485.3, scale=0, size=len(df_costco_acquisitions_lm_final))
random_values = np.clip(random_values,0 , 964590)
df_costco_acquisitions_lm_final['a_2x_costco_mbr',] = random_values.round().astype(int)

random_values = np.random.normal(loc=40.5, scale=0, size=len(df_costco_acquisitions_lm_final))
random_values = np.clip(random_values,0 , 8577)
df_costco_acquisitions_lm_final['n_2x_costco_mbr',] = random_values.round().astype(int)

random_values = np.random.normal(loc=14952.2, scale=136.5, size=len(df_costco_acquisitions_lm_final))
random_values = np.clip(random_values,0 , 907568)
df_costco_acquisitions_lm_final['a_4x_gas',] = random_values.round().astype(int)

random_values = np.random.normal(loc=523.9, scale=5, size=len(df_costco_acquisitions_lm_final))
random_values = np.clip(random_values,0 ,32404 )
df_costco_acquisitions_lm_final['n_4x_gas',] = random_values.round().astype(int)

random_values = np.random.normal(loc=19084.8, scale=0, size=len(df_costco_acquisitions_lm_final))
random_values = np.clip(random_values,-3529,1155427)
df_costco_acquisitions_lm_final['a_3x_travel',] = random_values.round().astype(int)

random_values = np.random.normal(loc=72.3, scale=0, size=len(df_costco_acquisitions_lm_final))
random_values = np.clip(random_values,0, 4207)
df_costco_acquisitions_lm_final['n_3x_travel',] = random_values.round().astype(int)

random_values = np.random.normal(loc=36997.5, scale=364.5, size=len(df_costco_acquisitions_lm_final))
random_values = np.clip(random_values, 0,2230750 )
df_costco_acquisitions_lm_final['a_3x_restaurant',] = random_values.round().astype(int)

random_values = np.random.normal(loc=1374.39, scale=13, size=len(df_costco_acquisitions_lm_final))
random_values = np.clip(random_values, 0, 85832)
df_costco_acquisitions_lm_final['n_3x_restaurant',] = random_values.round().astype(int)

random_values = np.random.normal(loc=331880.6, scale=2880.5, size=len(df_costco_acquisitions_lm_final))
random_values = np.clip(random_values,-764,20638831 )
df_costco_acquisitions_lm_final['a_1x_other',] = random_values.round().astype(int)

random_values = np.random.normal(loc=4152.8, scale=44, size=len(df_costco_acquisitions_lm_final))
random_values = np.clip(random_values,0 , 257070)
df_costco_acquisitions_lm_final[    'n_1x_other',] = random_values.round().astype(int)

random_values = np.random.normal(loc=148271.6, scale=1338, size=len(df_costco_acquisitions_lm_final))
random_values = np.clip(random_values,-825 ,8927351 )
df_costco_acquisitions_lm_final['a_trans_amt_online',] = random_values.round().astype(int)

random_values = np.random.normal(loc=1607.2, scale=17, size=len(df_costco_acquisitions_lm_final))
random_values = np.clip(random_values,0 , 93474)
df_costco_acquisitions_lm_final['n_trans_online',] = random_values.round().astype(int)

random_values = np.random.normal(loc=154136.9, scale=1562.5, size=len(df_costco_acquisitions_lm_final))
random_values = np.clip(random_values,-499,9984016)
df_costco_acquisitions_lm_final['a_cco',] = random_values.round().astype(int)

random_values = np.random.normal(loc=1585, scale=19, size=len(df_costco_acquisitions_lm_final))
random_values = np.clip(random_values,0 , 103652)
df_costco_acquisitions_lm_final['n_cco',] = random_values.round().astype(int)

random_values = np.random.normal(loc=402916.1, scale=3985, size=len(df_costco_acquisitions_lm_final))
random_values = np.clip(random_values, -661, 24859042)
df_costco_acquisitions_lm_final['a_non_cco',] = random_values.round().astype(int)

random_values = np.random.normal(loc=6123.5, scale=69.5, size=len(df_costco_acquisitions_lm_final))
random_values = np.clip(random_values,0 ,379433 )
df_costco_acquisitions_lm_final['n_non_cco',] = random_values.round().astype(int)

random_values = np.random.normal(loc=557053.40, scale=6151, size=len(df_costco_acquisitions_lm_final))
random_values = np.clip(random_values,-35 ,34843058 )
df_costco_acquisitions_lm_final['a_total',] = random_values.round().astype(int)

random_values = np.random.normal(loc=7708.5, scale=87, size=len(df_costco_acquisitions_lm_final))
random_values = np.clip(random_values, 0, 483085)
df_costco_acquisitions_lm_final['n_total',] = random_values.round().astype(int)

random_values = np.random.normal(loc=8955.4, scale=89.5, size=len(df_costco_acquisitions_lm_final))
random_values = np.clip(random_values,-8 , 550774)
df_costco_acquisitions_lm_final['a_interchange',] = random_values.round().astype(int)

random_values = np.random.normal(loc=811557, scale=2456, size=len(df_costco_acquisitions_lm_final))
random_values = np.clip(random_values,-509 ,61042473 )
df_costco_acquisitions_lm_final['goto_bal_revolving',] = random_values.round().astype(int)


random_values = np.random.normal(loc=8955.4, scale=89.5, size=len(df_costco_acquisitions_lm_final))
random_values = np.clip(random_values,-8 , 550774)
df_costco_acquisitions_lm_final['a_interchange',] = random_values.round().astype(int)


random_values = np.random.normal(loc=811557, scale=2456, size=len(df_costco_acquisitions_lm_final))
random_values = np.clip(random_values,-509 ,61042473 )
df_costco_acquisitions_lm_final['goto_bal_revolving',] = random_values.round().astype(int)


random_values = np.random.normal(loc=1773306.3, scale=87225.5, size=len(df_costco_acquisitions_lm_final))
random_values = np.clip(random_values, 0,83024748 )
df_costco_acquisitions_lm_final['tt_card_num',] = random_values.round().astype(int)


random_values = np.random.normal(loc=708.3, scale=27.5, size=len(df_costco_acquisitions_lm_final))
random_values = np.clip(random_values, 0,32023 )
df_costco_acquisitions_lm_final['tt_card_accts',] = random_values.round().astype(int)

random_values = np.random.normal(loc=114.2, scale=0, size=len(df_costco_acquisitions_lm_final))
random_values = np.clip(random_values, 0,7159 )
df_costco_acquisitions_lm_final['cycle_interest_cr_amt',] = random_values.round().astype(int)


random_values = np.random.normal(loc=9497.7, scale=102, size=len(df_costco_acquisitions_lm_final))
random_values = np.clip(random_values,-1, 592170)
df_costco_acquisitions_lm_final['rebate_cost'] = random_values.round().astype(int)



df_costco_acquisitions_lm_final
# Out:
#     per_num pid_segment vintage_month  mob vintage_quarter       channel_info  \
# 0      6454         520       V202210   20         2022 Q3          Warehouse
# 1      6454         520       V202211   18         2022 Q3       Citi Digital
# 2      6454         520       V202206   19         2022 Q2  Costco Collateral
# 3      6454         520       V202210   20         2022 Q3          Warehouse
# 4      6454         520       V202206   23         2022 Q1          Warehouse
# ..      ...         ...           ...  ...             ...                ...
# 995    6454         520       V202204   23         2022 Q4          Warehouse
# 996    6454         520       V202208   21         2022 Q3  Costco Collateral
# 997    6454         520       V202210   24         2022 Q4          Warehouse
# 998    6454         520       V202204   24         2022 Q3          Warehouse
# 999    6454         520       V202210   25         2022 Q2     Costco Digital
#
# ...

# %%
table_name = 'costco_acquisitions_lm_final_'
df_costco_acquisitions_lm_final.columns = [table_name + str(i) for i in df_costco_acquisitions_lm_final.columns]

df_info = pd.DataFrame(columns=['column_name', 'Data_type'])
df_info['column_name'] = df_costco_acquisitions_lm_final.columns.tolist()
for i in range(df_info.shape[0]):
    df_info['Data_type'][i] = df_costco_acquisitions_lm_final.iloc[:, i].dtype

df_costco_acquisitions_lm_final.to_csv('df_costco_acquisitions_lm_final.csv', index=False)
df_info.to_csv('df_costco_acquisitions_lm_final_info.csv', index=False)

df_info
# Out:
#                                            column_name Data_type
# 0                 costco_acquisitions_lm_final_per_num    object
# 1             costco_acquisitions_lm_final_pid_segment    object
# 2           costco_acquisitions_lm_final_vintage_month    object
# 3                     costco_acquisitions_lm_final_mob     int64
# 4         costco_acquisitions_lm_final_vintage_quarter    object
# ..                                                 ...       ...
# 119    costco_acquisitions_lm_final_('a_interchange',)     int64
# 120  costco_acquisitions_lm_final_('goto_bal_revolv...     int64
# 121      costco_acquisitions_lm_final_('tt_card_num',)     int64
# 122    costco_acquisitions_lm_final_('tt_card_accts',)     int64
# 123  costco_acquisitions_lm_final_('cycle_interest_...     int64
#
# [124 rows x 2 columns]
